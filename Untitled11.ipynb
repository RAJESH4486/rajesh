# %% [markdown]
# <a href="https://colab.research.google.com/github/RAJESH4486/rajesh/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input ('enter any text:'))
# Out:
# enter any text:hi have a bab day

# %%
a.save("speech1.mp3")

# %%
Audio('speech1.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install speechrecognition  pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 32.3 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as sr
from pydub import AudioSegment
mp3_file='/content/speech1.mp3'
wav_file='/content/speech1.wav'
audio = AudioSegment.from_mp3(mp3_file)
audio.export("audio.wav",format='wav')
# Out:
# <_io.BufferedRandom name='audio.wav'>

# %%
import speech_recognition as sr
reco=sr.Recognizer()
with sr.AudioFile('/content/audio.wav') as source:
  audio_data=reco.record(source)
  print('transcript:',reco.recognize_google(audio_data))
# Out:
# transcript: I have a bad day

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/download.png"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(240.5), np.float64(208.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text:",text)
# Out:
# Extracted text: Dew Kaen,
#
# edn gio. robitic,
#
# anion ing masdinin Hah wa
#
# at ay re
# mesaage, Te ul ti, eid ntl
#
# init pox ad g
#
# Ty it day
# “te, Rebit

# %%
from gtts import gTTS

# %%
a=gTTS(text)
a.save("speech2.mp3")

# %%
Audio("/content/speech2.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t=Translator()
text=input('enter any text:')
translated=t.translate(text,src='en',dest='te')
print("Transilated text",translated.text)
# Out:
# enter any text:hi
# Transilated text హాయ్
