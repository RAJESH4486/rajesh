# %% [markdown]
# <a href="https://colab.research.google.com/github/RAJESH4486/rajesh/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sb

# %%
aa=pd.read_csv("/content/matches.csv")

# %%
aa
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1      2    2017       Pune  6/4/2017               Mumbai Indians
# 2      3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3      4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
aa.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
aa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
aa['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan],
#       dtype=object)

# %%
aa['date'].unique()
# Out:
# array(['5/4/2017', '6/4/2017', '7/4/2017', '8/4/2017', '9/4/2017',
#        '10/4/2017', '11/4/2017', '12/4/2017', '13/04/17', '14/04/17',
#        '15/04/17', '16/04/17', '17/04/17', '18/04/17', '19/04/17',
#        '20/04/17', '21/04/17', '22/04/17', '23/04/17', '24/04/17',
#        '26/04/17', '27/04/17', '28/04/17', '29/04/17', '30/04/17',
#        '1/5/2017', '2/5/2017', '3/5/2017', '4/5/2017', '5/5/2017',
#        '6/5/2017', '7/5/2017', '8/5/2017', '9/5/2017', '10/5/2017',
#        '11/5/2017', '12/5/2017', '13/05/17', '14/05/17', '16/05/17',
#        '17/05/17', '19/05/17', '21/05/17', '18/04/08', '19/04/08',
#        '20/04/08', '21/04/08', '22/04/08', '23/04/08', '24/04/08',
#        '25/04/08', '26/04/08', '27/04/08', '28/04/08', '29/04/08',
#        '30/04/08', '1/5/2008', '2/5/2008', '25/05/08', '3/5/2008',
#        '4/5/2008', '5/5/2008', '6/5/2008', '7/5/2008', '8/5/2008',
#        '9/5/2008', '28/05/08', '10/5/2008', '11/5/2008', '12/5/2008',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
aa['city']=l.fit_transform(aa['city'])

# %%
aa['team1']=l.fit_transform(aa['team1'])

# %%
aa['team2']=l.fit_transform(aa['team2'])

# %%
aa['toss_winner']=l.fit_transform(aa['toss_winner'])

# %%
aa['toss_decision']=l.fit_transform(aa['toss_decision'])

# %%
aa['result']=l.fit_transform(aa['result'])

# %%
aa['winner']=l.fit_transform(aa['winner'])

# %%
aa['venue']=l.fit_transform(aa['venue'])

# %%
aa['city'].unique()
# Out:
# array([13, 24, 26, 14,  2, 21, 20,  9,  6, 17, 15,  7,  4, 23, 11,  5, 12,
#        16, 18,  3,  1,  8, 22, 10, 19, 29, 25, 27,  0, 28, 30])

# %%
aa['team1'].unique()
# Out:
# array([13,  7,  3, 10, 12,  6,  2,  4,  0,  9,  1,  5,  8, 11])

# %%
aa['team2'].unique()
# Out:
# array([12, 10,  6,  4,  2, 13,  7,  3,  9,  0,  1,  8,  5, 11])

# %%
aa['toss_winner'].unique()
# Out:
# array([12, 10,  6,  4, 13,  7,  3,  2,  0,  9,  1,  5,  8, 11])

# %%
aa['toss_decision'].unique()
# Out:
# array([1, 0])

# %%
aa['result'].unique()
# Out:
# array([1, 2, 0])

# %%
aa['winner'].unique()
# Out:
# array([13, 10,  6,  4, 12,  7,  2,  3,  0,  9,  1,  8,  5, 14, 11])

# %%
aa['venue'].unique()
# Out:
# array([23, 16, 25, 11, 14, 34,  7,  8, 21,  9, 22, 26, 15,  4, 19, 30, 13,
#        32,  2, 18,  3, 20,  1, 24,  0, 33, 10, 17,  5, 31, 27, 12, 29, 28,
#         6])

# %%
aa
# Out:
#      city  team1  team2  toss_winner  toss_decision  result  winner  \
# 0      13     13     12           12              1       1      13
# 1      24      7     10           10              1       1      10
# 2      26      3      6            6              1       1       6
# 3      14     10      4            4              1       1       4
# 4       2     12      2           12              0       1      12
# ..    ...    ...    ...          ...            ...     ...     ...
# 631    25      2     12           12              1       1      12
# 632     2      3     12           12              1       1      12
# 633     9     13      6            6              1       1      13
# 634     9      3     13           13              1       1      13
# 635     2     13     12           13              0       1      13
#
#      win_by_runs  win_by_wickets  venue
# 0             35               0     23
# 1              0               7     16
# ...

# %%
aa.corr()
# Out:
#                     city     team1     team2  toss_winner  toss_decision  \
# city            1.000000  0.034595 -0.003628     0.074606      -0.067335
# team1           0.034595  1.000000 -0.097257     0.393184       0.091780
# team2          -0.003628 -0.097257  1.000000     0.499329       0.037242
# toss_winner     0.074606  0.393184  0.499329     1.000000       0.091414
# toss_decision  -0.067335  0.091780  0.037242     0.091414       1.000000
# result         -0.021720  0.024871 -0.017249    -0.002144      -0.007179
# winner          0.011933  0.416290  0.495363     0.463588       0.096064
# win_by_runs    -0.058012  0.003662  0.022854    -0.047996       0.020516
# win_by_wickets  0.020335  0.010228  0.017123     0.071231       0.001609
# venue           0.074978  0.100745  0.067055     0.102239      -0.042932
#
#                   result    winner  win_by_runs  win_by_wickets     venue
# city           -0.021720  0.011933    -0.058012        0.020335  0.074978
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=aa.drop(['winner'],axis=1)
y=aa['winner']

# %%
x
# Out:
#      city  team1  team2  toss_winner  toss_decision  result  win_by_runs  \
# 0      13     13     12           12              1       1           35
# 1      24      7     10           10              1       1            0
# 2      26      3      6            6              1       1            0
# 3      14     10      4            4              1       1            0
# 4       2     12      2           12              0       1           15
# ..    ...    ...    ...          ...            ...     ...          ...
# 631    25      2     12           12              1       1            0
# 632     2      3     12           12              1       1            0
# 633     9     13      6            6              1       1           22
# 634     9      3     13           13              1       1            0
# 635     2     13     12           13              0       1            8
#
#      win_by_wickets  venue
# 0                 0     23
# 1                 7     16
# ...

# %%
y
# Out:
# 0      13
# 1      10
# 2       6
# 3       4
# 4      12
#        ..
# 631    12
# 632    12
# 633    13
# 634    13
# 635    13
# Name: winner, Length: 636, dtype: int64

# %%
aa.corr()
# Out:
#                     city     team1     team2  toss_winner  toss_decision  \
# city            1.000000  0.034595 -0.003628     0.074606      -0.067335
# team1           0.034595  1.000000 -0.097257     0.393184       0.091780
# team2          -0.003628 -0.097257  1.000000     0.499329       0.037242
# toss_winner     0.074606  0.393184  0.499329     1.000000       0.091414
# toss_decision  -0.067335  0.091780  0.037242     0.091414       1.000000
# result         -0.021720  0.024871 -0.017249    -0.002144      -0.007179
# winner          0.011933  0.416290  0.495363     0.463588       0.096064
# win_by_runs    -0.058012  0.003662  0.022854    -0.047996       0.020516
# win_by_wickets  0.020335  0.010228  0.017123     0.071231       0.001609
# venue           0.074978  0.100745  0.067055     0.102239      -0.042932
#
#                   result    winner  win_by_runs  win_by_wickets     venue
# city           -0.021720  0.011933    -0.058012        0.020335  0.074978
# ...

# %%
xtrain, xtest, ytrain, ytest, = train_test_split(x,y, test_size=0.25)

# %%
xtest
# Out:
#      city  team1  team2  toss_winner  toss_decision  result  win_by_runs  \
# 533     2      7     12           12              1       1           18
# 550    13     13      0            0              1       1           22
# 567    13     13     12           13              0       1            0
# 505    20      6     12           12              1       1           30
# 416    21      7     12            7              0       1           58
# ..    ...    ...    ...          ...            ...     ...          ...
# 312    29      0      1            1              1       1           74
# 554    20      6     13           13              1       1           35
# 279     2     12      4            4              1       1           85
# 384     9      9      2            9              0       1            5
# 42     13     10     13           13              1       1           12
#
#      win_by_wickets  venue
# 533               0     14
# 550               0     23
# ...

# %%
ytest
# Out:
# 533     7
# 550    13
# 567    12
# 505     6
# 416     7
#        ..
# 312     0
# 554     6
# 279    12
# 384     9
# 42     10
# Name: winner, Length: 159, dtype: int64

# %%
sb.pairplot(aa, hue='winner')

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain, ytrain)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ypred = lr.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest, ypred)
# Out:
# 0.2389937106918239

# %%
import pickle

# %%
pickle.dump(lr, open('ipl.pkl', 'wb'))
